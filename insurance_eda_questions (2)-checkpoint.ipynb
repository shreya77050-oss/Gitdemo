# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\uhsna\Desktop\S\Shree\Data Analyst\Session\Python\seaborn\insurance_synthetic_data.xls")
df.head()
# Out:
#    age gender   bmi  bloodpressure diabetic  children smoker     region  \
# 0   56   male  23.5            153      Yes         2     No  northeast
# 1   46   male  28.1            133       No         2     No  southwest
# 2   32   male  26.4            142      Yes         1     No  southeast
# 3   60   male  25.9            113      Yes         3     No  northeast
# 4   25   male  30.1            149      Yes         4    Yes  northwest
#
#       claim   charges
# 0  28309.76  24457.66
# 1  19454.47  17312.84
# 2  25998.33  21362.60
# 3  29782.52  26696.27
# 4  37532.64  35255.83

# %% [markdown]
# ### Q1: What are the dimensions of the dataset (rows & columns)?

# %%
df.shape
# Out:
# (500, 10)

# %% [markdown]
# ### Q2: What are the data types of each column?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            500 non-null    int64
#  1   gender         500 non-null    object
#  2   bmi            500 non-null    float64
#  3   bloodpressure  500 non-null    int64
#  4   diabetic       500 non-null    object
#  5   children       500 non-null    int64
#  6   smoker         500 non-null    object
#  7   region         500 non-null    object
#  8   claim          500 non-null    float64
#  9   charges        500 non-null    float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 39.2+ KB

# %% [markdown]
# ### Q3: Identify numerical and categorical columns.

# %%
numerical_col=df.select_dtypes(include='number')
numerical_col
# Out:
#      age   bmi  bloodpressure  children     claim   charges
# 0     56  23.5            153         2  28309.76  24457.66
# 1     46  28.1            133         2  19454.47  17312.84
# 2     32  26.4            142         1  25998.33  21362.60
# 3     60  25.9            113         3  29782.52  26696.27
# 4     25  30.1            149         4  37532.64  35255.83
# ..   ...   ...            ...       ...       ...       ...
# 495   37  29.3            143         3  17240.05  20121.49
# 496   41  29.8            141         3  34912.47  30287.79
# 497   29  29.2             92         1  14038.61  14084.07
# 498   52  30.2            130         1  19721.48  21462.30
# 499   50  33.6             95         3  22127.19  18369.71
#
# [500 rows x 6 columns]

# %%
categorical_col=df.select_dtypes(include='object')
categorical_col
# Out:
#      gender diabetic smoker     region
# 0      male      Yes     No  northeast
# 1      male       No     No  southwest
# 2      male      Yes     No  southeast
# 3      male      Yes     No  northeast
# 4      male      Yes    Yes  northwest
# ..      ...      ...    ...        ...
# 495    male       No     No  southeast
# 496    male       No    Yes  southeast
# 497  female       No     No  southeast
# 498    male       No     No  northeast
# 499    male       No     No  southwest
#
# [500 rows x 4 columns]

# %% [markdown]
# ### Q4: Are there any missing values in the dataset?

# %%
df.isnull().sum()
# Out:
# age              0
# gender           0
# bmi              0
# bloodpressure    0
# diabetic         0
# children         0
# smoker           0
# region           0
# claim            0
# charges          0
# dtype: int64

# %% [markdown]
# ### Q5: How many unique values are present in each categorical column?

# %%
categorical_col.nunique()
# Out:
# gender      2
# diabetic    2
# smoker      2
# region      4
# dtype: int64

# %%
for i in categorical_col:
    print(i,df[i].nunique())
# Out:
# gender 2
# diabetic 2
# smoker 2
# region 4

# %% [markdown]
# ### Q6: What is the distribution of premimum?

# %%
df=df.rename(columns={'premimum':'premium'})
df.head()
# Out:
#    age gender   bmi  bloodpressure diabetic  children smoker     region  \
# 0   56   male  23.5            153      Yes         2     No  northeast
# 1   46   male  28.1            133       No         2     No  southwest
# 2   32   male  26.4            142      Yes         1     No  southeast
# 3   60   male  25.9            113      Yes         3     No  northeast
# 4   25   male  30.1            149      Yes         4    Yes  northwest
#
#       claim   premium
# 0  28309.76  24457.66
# 1  19454.47  17312.84
# 2  25998.33  21362.60
# 3  29782.52  26696.27
# 4  37532.64  35255.83

# %%
sns.set_theme(style='white',palette='pastel')
sns.histplot(x='premimum',data=df,kde=True)
# Out:
# <Axes: xlabel='premimum', ylabel='Count'>

# %% [markdown]
# ### Q7: Is the distribution of premimum skewed? If yes, in which direction?

# %% [markdown]
# #### ANS : Yes , it is skewed in right direction.

# %% [markdown]
# ### Q8: What are the summary statistics of premium?

# %%
df['premium'].describe()
# Out:
# count      500.000000
# mean     20978.795180
# std       6078.386111
# min       8636.040000
# 25%      16750.982500
# 50%      19453.720000
# 75%      24394.202500
# max      40510.960000
# Name: premium, dtype: float64

# %% [markdown]
# ### Q9: Are there any outliers in premimum?

# %%
sns.boxplot(x='premium',data=df)
# Out:
# <Axes: xlabel='premium'>

# %% [markdown]
# ### Q10: What is the distribution of age?

# %%
sns.histplot(x='age',data=df,kde=True)
plt.title('Distribution of age')
# Out:
# Text(0.5, 1.0, 'Distribution of age')

# %% [markdown]
# ### Q11: What is the distribution of BMI?

# %%
sns.histplot(x='bmi',data=df,kde=True)
plt.title('Distribution of BMI')
# Out:
# Text(0.5, 1.0, 'Distribution of BMI')

# %% [markdown]
# ### Q12: What is the distribution of number of children?

# %%
df.head()
# Out:
#    age gender   bmi  bloodpressure diabetic  children smoker     region  \
# 0   56   male  23.5            153      Yes         2     No  northeast
# 1   46   male  28.1            133       No         2     No  southwest
# 2   32   male  26.4            142      Yes         1     No  southeast
# 3   60   male  25.9            113      Yes         3     No  northeast
# 4   25   male  30.1            149      Yes         4    Yes  northwest
#
#       claim   premium
# 0  28309.76  24457.66
# 1  19454.47  17312.84
# 2  25998.33  21362.60
# 3  29782.52  26696.27
# 4  37532.64  35255.83

# %%
sns.countplot(x='children',data=df)
plt.title('Distribution of number of Children')
# Out:
# Text(0.5, 1.0, 'Distribution of number of Children')

# %% [markdown]
# ### Q13: What is the gender distribution?

# %%
sns.countplot(x='gender',data=df)
plt.title('Distribution of gender')
# Out:
# Text(0.5, 1.0, 'Distribution of gender')

# %% [markdown]
# ### Q14: What is the smoker distribution?

# %%
sns.countplot(x='smoker',data=df)
plt.title('Distribution of smokers')
# Out:
# Text(0.5, 1.0, 'Distribution of smokers')

# %% [markdown]
# ### Q15: What is the region distribution?

# %%
sns.countplot(x='region',data=df)
plt.title('Distribution of region')
# Out:
# Text(0.5, 1.0, 'Distribution of region')

# %% [markdown]
# ### Q16: Does smoking affect medical premimum?

# %%
sns.histplot(x='smoker',y='premium',data=df,kde=True)
# Out:
# <Axes: xlabel='smoker', ylabel='premium'>

# %%
sns.barplot(x='smoker',y='premium',data=df)
plt.title('Barplot of smoker v/s premium')
# Out:
# Text(0.5, 1.0, 'Barplot of smoker v/s premium')

# %% [markdown]
# ### Q17: What is the relationship between BMI and premimum?

# %%
sns.scatterplot(x='bmi',y='premium',data=df)
plt.title('Positive Correlation between BMI & Premium')
# Out:
# Text(0.5, 1.0, 'Positive Correlation between BMI & Premium')

# %% [markdown]
# #### Ans: Majority of the people paying premium lie in the bmi range of 27 to 32 and they premium of 12000 to 22000 . With increase in bmi the premium also increases so , it's Positive correlation between bmi and premium

# %% [markdown]
# ### Q18: How does smoking influence the BMI vs premimum relationship?

# %%
sns.scatterplot(x='bmi',y='premium',data=df,hue='smoker')
plt.title('Smoking influence BMI v/s Premium')
# Out:
# Text(0.5, 1.0, 'Smoking influence BMI v/s Premium')

# %% [markdown]
# ### Q19: What is the relationship between age and premimum?

# %%
sns.lineplot(x='age',y='premium',data=df)
plt.title('Positive Correlation between Age & Premium')
# Out:
# Text(0.5, 1.0, 'Positive Correlation between Age & Premium')

# %% [markdown]
# ### Q20: Do males and females differ in premimum?

# %%
sns.lineplot(x='gender',y='premium',data=df)
plt.title('Gender v/s Premium')
# Out:
# Text(0.5, 1.0, 'Gender v/s Premium')

# %% [markdown]
# ### Q21: Does the number of children affect premimum?

# %%
sns.lineplot(x='children',y='premium',data=df)
plt.title('Number of children v/s Premium')
# Out:
# Text(0.5, 1.0, 'Number of children v/s Premium')

# %% [markdown]
# ### Q22: Does region affect premimum?

# %%
sns.lineplot(x='region',y='premium',data=df)
plt.title('Region v/s Premium')
# Out:
# Text(0.5, 1.0, 'Region v/s Premium')

# %% [markdown]
# ### Q23: What are the pairwise relationships between variables?

# %%
sns.pairplot(df,hue='smoker')

# %% [markdown]
# ### Q24: What does the correlation heatmap reveal?

# %%
correlation=numerical_col.corr()

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Q25: Which feature is most correlated with premimum?

# %%
correlation['charges'].sort_values(ascending=False)[1]
# Out:
# C:\Users\uhsna\AppData\Local\Temp\ipykernel_15624\4203378858.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   correlation['charges'].sort_values(ascending=False)[1]
# np.float64(0.9377465834587493)

# %% [markdown]
# ### Q26: How does age vs premimum differ by smoking status?

# %%
sns.scatterplot(x='age',y='premium',hue='smoker',data=df)
plt.title('Age v/s Premium differ by smoking status')
# Out:
# Text(0.5, 1.0, 'Age v/s Premium differ by smoking status')

# %% [markdown]
# ### Q27: What is the average charge for smokers vs non-smokers?

# %%
df.groupby('smoker')['premium'].mean()
# Out:
# smoker
# No     18769.167802
# Yes    30398.785579
# Name: premium, dtype: float64

# %% [markdown]
# ### Q28: What is the average charge by region?

# %%
df.groupby('region')['premium'].mean()
# Out:
# region
# northeast    21206.621838
# northwest    21152.372049
# southeast    20409.168605
# southwest    21167.476814
# Name: premium, dtype: float64

# %% [markdown]
# ### Q29: What is the average charge by gender?

# %%
df.groupby('gender')['premium'].mean()
# Out:
# gender
# female    20933.338559
# male      21017.206863
# Name: premium, dtype: float64

# %% [markdown]
# ### Q30: What is the average charge by number of children?

# %%
df.groupby('children')['premium'].mean()
# Out:
# children
# 0    18599.655288
# 1    20460.554615
# 2    21381.432321
# 3    22072.933980
# 4    22233.724352
# Name: premium, dtype: float64
